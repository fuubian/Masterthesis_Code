# %%
import os
import regex as re
import csv
import shutil

# %%
# Variables
source_dir = "source_files/"
source_metadata_file = source_dir + "papers.csv"
processed_metadata_file = source_dir + "papers_processed.csv"

table_output_dir = "extracted_tables/"
table_code_dir = table_output_dir + "table_code/"
table_result_file = table_output_dir + "tables.csv"

figure_output_dir = "extracted_figures/"
figure_result_file = figure_output_dir + "figures.csv"

possible_extensions = [".pdf", ".png", ".jpg", ".jpeg", ".eps", ".ps"]
WORD_THRESHOLD = 40
MAX_PROCESSING_TIME = 30

os.makedirs(table_output_dir, exist_ok=True)
os.makedirs(table_code_dir, exist_ok=True)
os.makedirs(figure_output_dir, exist_ok=True)

if os.path.isfile(table_result_file) == False:
    open(table_result_file, "w").close()
    
if os.path.isfile(figure_result_file) == False:
    open(figure_result_file, "w").close()
    
if os.path.isfile(processed_metadata_file) == False:
    open(processed_metadata_file, "w").close()

# %%
"""
Returns a list of papers that were downloaded but not yet processed.
"""
def get_unprocessed_papers():
    unprocessed_papers = []
    with open(source_metadata_file, "r") as csvfile_source:
        with open(processed_metadata_file, "r") as csvfile_processed:
            source_spamreader = csv.reader(csvfile_source, delimiter=';', quotechar='|', quoting=csv.QUOTE_ALL)
            processed_spamreader = csv.reader(csvfile_processed, delimiter=';', quotechar='|', quoting=csv.QUOTE_ALL)

            processed_papers = {row[0] for row in processed_spamreader}

            for row in source_spamreader:
                if row[0] not in processed_papers:
                    unprocessed_papers.append(row)
    
    return unprocessed_papers

# %%
"""
Extracting tables and figures from the downloaded papers in the source directory
"""
def extract_data_from_papers(unprocessed_papers, amount):
    for i in range(amount):
        row = unprocessed_papers[i]
        
        paper_id = row[0]
        paper_path = source_dir + paper_id
        if os.path.isdir(paper_path):
            print("\n\n", i, paper_id)
            tex_files = [os.path.join(root, file)
                 for root, dirs, files in os.walk(paper_path)
                 for file in files if file.endswith(".tex") and file.startswith("FR_") == False]
            print(tex_files)

            complete_tex = ""
            for file in tex_files:
                try:
                    f = open(file, "r", encoding="utf8")
                    complete_tex += f.read()
                    f.close()
                except UnicodeDecodeError as e:
                    print("UnicodeDecodeError occurred. File could not be loaded.")
                    continue
            
            try:
            
                # Search for table and figure structures
                found_tables = re.findall(r"\\begin\{table\*?\}.*?\\end\{table\*?\}", complete_tex, re.DOTALL, timeout=MAX_PROCESSING_TIME)
                found_figures = re.findall(r"\\begin\{figure\*?\}.*?\\end\{figure\*?\}", complete_tex, re.DOTALL, timeout=MAX_PROCESSING_TIME)
                counter_table = 0
                counter_figure = 0

                # Capture document preamble. If it can't be captured, skip table capturing.
                found_document_header = re.search(r"\\documentclass\[.*?\\begin\{document\}", complete_tex, re.DOTALL, timeout=MAX_PROCESSING_TIME)
                if found_document_header is None:
                    print("Document header could not be identified.")
                    found_tables = []

                # Table capturing
                for table in found_tables:
                    # Capturing and saving process
                    if capturing_process(table, "TABLE", paper_id, counter_table, complete_tex, document_header=found_document_header.group(0)):
                        counter_table += 1

                # Figure capturing
                for figure in found_figures:
                    # Locating graphic and skipping multi figures
                    found_graphics = re.findall(r"\\includegraphics(\[.*?\])*\{(.*?)\}", figure, timeout=MAX_PROCESSING_TIME)
                    if len(found_graphics) != 1:
                        continue

                    # Capturing and saving process
                    if capturing_process(figure, "FIGURE", paper_id, counter_figure, complete_tex, found_graphic=found_graphics[0]):
                        counter_figure += 1

                number_tables = len(found_tables)
                number_figures = len(found_figures)
                print(f"{counter_table}/{number_tables} tables collected.")
                print(f"{counter_figure}/{number_figures} figures collected.")

                # Storing information in final metadata file and removing the paper from disk
                finish_process(row, counter_table, counter_figure)
            except re.error as e:
                print(f"Regex error for {paper_id}: {e}")
        else:
            print(f"Paper {paper_id} could not be found.")
            finish_process(row, -1, -1)

# Capturing label, paragraph mentions and saving them into metadata file
def capturing_process(current_object, object_type, paper_id, counter, complete_tex, found_graphic=None, document_header=None):
    label_match = re.search(r"\\label\{(.*?)\}", current_object, timeout=MAX_PROCESSING_TIME)
    caption_match = re.search(r"\\caption\{.*\}", current_object, timeout=MAX_PROCESSING_TIME)
    paper_path = source_dir + paper_id

    if label_match and caption_match:
        found_caption = caption_match.group(0)
        found_label = label_match.group(1)
        
        # Skipping if no paragraph mention was found
        found_paragraphs = re.findall(fr".*\\ref\{{{re.escape(found_label)}}}.*", complete_tex, timeout=MAX_PROCESSING_TIME)
        if len(found_paragraphs) == 0:
            return False

        # Combining paragraph mentions
        paragraph_mentions = []
        for paragraph in found_paragraphs:
            paragraph_mentions.append(paragraph)
        paragraph_mentions = " ".join(paragraph_mentions)
            
        # Removing paragraph mentions if word length under threshold
        word_length = len(paragraph_mentions.split())
        if word_length < WORD_THRESHOLD:
            return False
        
        # Set object-related variables
        object_id = None
        result_file = None
        if object_type == "TABLE":
            object_id = paper_id + "_TAB_" + str(counter + 1)
            result_file = table_result_file
        elif object_type == "FIGURE":
            object_id = paper_id + "_FIG_" + str(counter + 1)
            result_file = figure_result_file

        # Object-related saving process
        if object_type == "TABLE":
            # Store as txt file
            table_file_path = table_code_dir + object_id + ".tex"
            table_tex_code = document_header + "\n\pagenumbering{gobble}\n" + current_object + "\n\end{document}"
            f = open(table_file_path, "w", encoding="utf-8")
            f.write(table_tex_code)
            f.close()
        elif object_type == "FIGURE":
            # Locate graphic path
            graphic_path = found_graphic[1]
            file_type = os.path.splitext(graphic_path)[-1]
            
            # Handling the case where the file type is not included in tex code
            if os.path.isfile(paper_path+"/"+graphic_path):
                graphic_path = paper_path+"/"+graphic_path
            else:
                unknown_extension = True
                for ext in possible_extensions:
                    possible_path = paper_path+"/"+graphic_path + ext
                    if os.path.isfile(possible_path):
                        graphic_path = possible_path
                        file_type = ext
                        unknown_extension = False
                        break
                if unknown_extension:
                    return False
            
            # Moving figure file to own dataset
            try:
                os.rename(graphic_path, figure_output_dir + object_id + file_type)
            except FileNotFoundError as e:
                print(f"File not found: {graphic_path} - {e}")
                return False
            except Exception as e:
                print(f"An error occurred: {e}")
                return False
        
        # Store meta information in csv file
        with open(result_file, 'a', newline='', encoding="utf-8") as csvfile:
            spamwriter = csv.writer(csvfile, delimiter=';', quotechar='|', quoting=csv.QUOTE_MINIMAL)
            spamwriter.writerow([object_id, paper_id, "https://arxiv.org/abs/" + paper_id, found_caption, paragraph_mentions])
        
        return True
            
# Store meta information in processed_papers csv file and deletes paper from disk if it is not longer needed
def finish_process(row, number_tables, number_figures):    
    # Write into processed_papers csv file
    with open(processed_metadata_file, "a", newline='', encoding="utf-8") as csvfile_processed:
        spamwriter = csv.writer(csvfile_processed, delimiter=';', quotechar='|', quoting=csv.QUOTE_MINIMAL)
        new_row = row + [str(number_tables), str(number_figures)]
        spamwriter.writerow(new_row)

    # Delete paper
    try:
        shutil.rmtree(source_dir + row[0])
    except Exception as e:
        print(f"Paper {row[0]} could not be deleted.")
        print(f"Error Type: {type(e).__name__}")
        error_message = str(e)[:100]
        print(f"Error Message: {error_message}")

# %%
## Get list of unprocessed papers
list_unprocessed_papers = get_unprocessed_papers()
print(f"Number of unprocessed papers: {len(list_unprocessed_papers)}")
# Out:
# Number of unprocessed papers: 1719

# %%
# Set how many processed papers should be processed
number_of_papers_to_process = 1719

# Start the processing process, including extraction
extract_data_from_papers(list_unprocessed_papers, number_of_papers_to_process)
# Out:
#  0 2310.05853
# ['source_files/2310.05853\\Exploring_User_Perceptions_of_Using_An_LLM-Based_Conversational_Assistant_Toward_Cooking_Partner.tex']
# 4/8 tables collected.
# 3/8 figures collected.
#
#
#  1 2310.05868
# ['source_files/2310.05868\\acknowledgments.tex', 'source_files/2310.05868\\acronym.tex', 'source_files/2310.05868\\cas-sc-template.tex', 'source_files/2310.05868\\conclusions.tex', 'source_files/2310.05868\\discussion.tex', 'source_files/2310.05868\\experiments_and_results.tex', 'source_files/2310.05868\\introduction.tex', 'source_files/2310.05868\\materials.tex', 'source_files/2310.05868\\model.tex']
# 0/0 tables collected.
# 5/5 figures collected.
#
#
#  2 2310.05871
# ['source_files/2310.05871\\template.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 0/5 figures collected.
#
#
#  3 2310.05881
# ['source_files/2310.05881\\emnlp.tex']
# 4/6 tables collected.
# 5/6 figures collected.
#
#
#  4 2310.05911
# ['source_files/2310.05911\\main.tex']
# 0/0 tables collected.
# 4/4 figures collected.
#
#
#  5 2310.05915
# ['source_files/2310.05915\\appendix.tex', 'source_files/2310.05915\\main.tex', 'source_files/2310.05915\\math_commands.tex', 'source_files/2310.05915\\prompts\\hotpot.tex', 'source_files/2310.05915\\prompts\\mmlu.tex', 'source_files/2310.05915\\prompts\\strategyqa.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 3/6 figures collected.
#
#
#  6 2310.05918
# ['source_files/2310.05918\\grokking_compression.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 3/4 figures collected.
#
#
#  7 2301.08707
# ['source_files/2301.08707\\fig-NS-fabio.tex', 'source_files/2301.08707\\fig-rotation-fabio.tex', 'source_files/2301.08707\\fig-separation-fabio.tex', 'source_files/2301.08707\\separating_paths_aic_template.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 0/3 figures collected.
#
#
#  8 2302.10243
# ['source_files/2302.10243\\main.tex']
# 0/0 tables collected.
# 20/20 figures collected.
#
#
#  9 2302.11520
# ['source_files/2302.11520\\math_commands.tex', 'source_files/2302.11520\\neurips_2023.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 6/10 figures collected.
#
#
#  10 2303.04475
# ['source_files/2303.04475\\main.tex']
# 3/3 tables collected.
# 2/3 figures collected.
#
#
#  11 2303.07925
# ['source_files/2303.07925\\additionalresults.tex', 'source_files/2303.07925\\templateArxiv.tex']
# 9/20 tables collected.
# 9/32 figures collected.
#
#
#  12 2303.09325
# ['source_files/2303.09325\\main.tex']
# 7/7 tables collected.
# 0/6 figures collected.
#
#
#  13 2303.11366
# ['source_files/2303.11366\\main.tex', 'source_files/2303.11366\\additional_information\\decisionmaking.tex', 'source_files/2303.11366\\additional_information\\othermodels.tex', 'source_files/2303.11366\\additional_information\\programming.tex', 'source_files/2303.11366\\additional_information\\reasoning.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 1/11 figures collected.
#
#
#  14 2304.00818
# ['source_files/2304.00818\\acronyms.tex', 'source_files/2304.00818\\asmr.tex', 'source_files/2304.00818\\math_commands.tex', 'source_files/2304.00818\\appendix\\experiments.tex', 'source_files/2304.00818\\appendix\\generalization_runtime.tex', 'source_files/2304.00818\\appendix\\hyperparameters.tex', 'source_files/2304.00818\\appendix\\method.tex', 'source_files/2304.00818\\appendix\\results.tex', 'source_files/2304.00818\\appendix\\tasks.tex', 'source_files/2304.00818\\appendix\\visualizations.tex', 'source_files/2304.00818\\appendix\\_ablations.tex', 'source_files/2304.00818\\appendix\\_element_penalty_quantitative.tex', 'source_files/2304.00818\\appendix\\_generalization1x1.tex', 'source_files/2304.00818\\appendix\\_generalization20x20.tex', 'source_files/2304.00818\\appendix\\_generalization_quantitative.tex', 'source_files/2304.00818\\appendix\\_generalization_runtime.tex', 'source_files/2304.00818\\appendix\\_generalization_training.tex', 'source_files/2304.00818\\appendix\\_ppo_dqn_gat.tex', 'source_files/2304.00818\\appendix\\_quantitative_additional_metrics.tex', 'source_files/2304.00818\\appendix\\_runtime.tex', 'source_files/2304.00818\\appendix\\_zz_error.tex', 'source_files/2304.00818\\figures\\qualitative_results\\all_tasks_main_paper\\latex_code.tex', 'source_files/2304.00818\\figures\\qualitative_results\\extrapolation\\latex_code.tex', 'source_files/2304.00818\\figures\\qualitative_results\\heat_diffusion_asmr\\latex_code.tex', 'source_files/2304.00818\\figures\\qualitative_results\\heat_diffusion_main_paper\\latex_code.tex', 'source_files/2304.00818\\figures\\qualitative_results\\laplace_ours\\latex_code.tex', 'source_files/2304.00818\\figures\\qualitative_results\\linear_elasticity_ours\\latex_code.tex', 'source_files/2304.00818\\figures\\qualitative_results\\marking_strategy\\latex_code.tex', 'source_files/2304.00818\\figures\\qualitative_results\\poisson_argmax\\latex_code.tex', 'source_files/2304.00818\\figures\\qualitative_results\\poisson_local_maximum_oracle\\latex_code.tex', 'source_files/2304.00818\\figures\\qualitative_results\\poisson_local_oracle\\latex_code.tex', 'source_files/2304.00818\\figures\\qualitative_results\\poisson_ours\\latex_code.tex', 'source_files/2304.00818\\figures\\qualitative_results\\poisson_sweep\\latex_code.tex', 'source_files/2304.00818\\figures\\qualitative_results\\poisson_vdgn\\latex_code.tex', 'source_files/2304.00818\\figures\\qualitative_results\\poisson_zzerror\\latex_code.tex', 'source_files/2304.00818\\figures\\qualitative_results\\stokes_flow_asmr\\latex_code.tex', 'source_files/2304.00818\\figures\\quantitative_results\\group_laplace.tex', 'source_files/2304.00818\\figures\\quantitative_results\\group_laplace_1.tex', 'source_files/2304.00818\\figures\\quantitative_results\\group_laplace_2.tex', 'source_files/2304.00818\\figures\\quantitative_results\\group_main.tex', 'source_files/2304.00818\\figures\\quantitative_results\\group_main_1.tex', 'source_files/2304.00818\\figures\\quantitative_results\\group_main_2.tex', 'source_files/2304.00818\\figures\\quantitative_results\\group_main_3.tex', 'source_files/2304.00818\\figures\\quantitative_results\\group_main_4.tex', 'source_files/2304.00818\\figures\\quantitative_results\\legend_main.tex', 'source_files/2304.00818\\figures\\quantitative_results\\legend_reward_ablations.tex', 'source_files/2304.00818\\figures\\quantitative_results\\reward_ablations.tex', 'source_files/2304.00818\\figures\\quantitative_results\\appendix\\group_ablations.tex', 'source_files/2304.00818\\figures\\quantitative_results\\appendix\\group_ablations_1.tex', 'source_files/2304.00818\\figures\\quantitative_results\\appendix\\group_ablations_2.tex', 'source_files/2304.00818\\figures\\quantitative_results\\appendix\\group_additional_metrics.tex', 'source_files/2304.00818\\figures\\quantitative_results\\appendix\\group_additional_metrics_l1.tex', 'source_files/2304.00818\\figures\\quantitative_results\\appendix\\group_additional_metrics_l2.tex',  ...
# Document header could not be identified.
# 0/0 tables collected.
# 0/30 figures collected.
#
#
#  15 2304.01002
# ['source_files/2304.01002\\abstract.tex', 'source_files/2304.01002\\acknowledgment.tex', 'source_files/2304.01002\\conclusion.tex', 'source_files/2304.01002\\discussion.tex', 'source_files/2304.01002\\ethics.tex', 'source_files/2304.01002\\introduction.tex', 'source_files/2304.01002\\limitation.tex', 'source_files/2304.01002\\literature.tex', 'source_files/2304.01002\\main.tex', 'source_files/2304.01002\\method.tex', 'source_files/2304.01002\\method_copy.tex', 'source_files/2304.01002\\result.tex', 'source_files/2304.01002\\settings.tex', 'source_files/2304.01002\\title.tex']
# 10/21 tables collected.
# 3/18 figures collected.
#
#
#  16 2304.09654
# ['source_files/2304.09654\\algorithm-exact.tex', 'source_files/2304.09654\\introduction.tex', 'source_files/2304.09654\\preliminaries.tex', 'source_files/2304.09654\\temporal-cm.tex', 'source_files/2304.09654\\tgs-main.tex', 'source_files/2304.09654\\thm2-proof.tex', 'source_files/2304.09654\\figures\\d_switching.tex', 'source_files/2304.09654\\figures\\switching_TD.tex', 'source_files/2304.09654\\figures\\switching_TL.tex', 'source_files/2304.09654\\figures\\tcm-outputs.tex']
# 0/0 tables collected.
# 0/2 figures collected.
#
#
#  17 2304.09846
# ['source_files/2304.09846\\abstract.tex', 'source_files/2304.09846\\applications.tex', 'source_files/2304.09846\\intro.tex', 'source_files/2304.09846\\macros.tex', 'source_files/2304.09846\\main.tex', 'source_files/2304.09846\\prelim.tex', 'source_files/2304.09846\\qip.tex']
# 0/0 tables collected.
# 0/1 figures collected.
#
#
#  18 2304.13828
# ['source_files/2304.13828\\manuscript.tex']
# 2/2 tables collected.
# 7/7 figures collected.
#
#
#  19 2305.00067
# ['source_files/2305.00067\\main.tex']
# 2/3 tables collected.
# 3/3 figures collected.
#
#
#  20 2305.05456
# ['source_files/2305.05456\\root.tex']
# 0/0 tables collected.
# 2/10 figures collected.
#
#
#  21 2305.11877
# ['source_files/2305.11877\\main.tex']
# 0/0 tables collected.
# 0/1 figures collected.
#
#
#  22 2305.12660
# ['source_files/2305.12660\\000abstract.tex', 'source_files/2305.12660\\010intro.tex', 'source_files/2305.12660\\020related.tex', 'source_files/2305.12660\\030method.tex', 'source_files/2305.12660\\040data.tex', 'source_files/2305.12660\\055exevalu.tex', 'source_files/2305.12660\\060conclusion.tex', 'source_files/2305.12660\\070limitation.tex', 'source_files/2305.12660\\080Ethics.tex', 'source_files/2305.12660\\090appendix.tex', 'source_files/2305.12660\\main.tex', 'source_files/2305.12660\\table\\010stastics.tex', 'source_files/2305.12660\\table\\020compare.tex', 'source_files/2305.12660\\table\\030word_analogy.tex', 'source_files/2305.12660\\table\\050ScienceQA.tex', 'source_files/2305.12660\\table\\060Example_word_analogy.tex', 'source_files/2305.12660\\table\\070template_word_analogy.tex', 'source_files/2305.12660\\table\\080template_scienceqa.tex', 'source_files/2305.12660\\table\\090template_example.tex', 'source_files/2305.12660\\table\\100template_backgroud_explanation.tex', 'source_files/2305.12660\\table\\110template_structure.tex', 'source_files/2305.12660\\table\\120template_structure_back_expl.tex', 'source_files/2305.12660\\table\\130template_structure_open.tex', 'source_files/2305.12660\\table\\140overall.tex', 'source_files/2305.12660\\table\\150ScienceQA_cot.tex', 'source_files/2305.12660\\table\\ChatGPT.tex', 'source_files/2305.12660\\table\\GPT-4.tex', 'source_files/2305.12660\\table\\InstructGPT.tex', 'source_files/2305.12660\\table\\template.tex', 'source_files/2305.12660\\table\\template_bar.tex']
# 1/16 tables collected.
# 0/6 figures collected.
#
#
#  23 2305.14829
# ['source_files/2305.14829\\FinalCamera.tex']
# 1/1 tables collected.
# 9/19 figures collected.
#
#
#  24 2305.15011
# ['source_files/2305.15011\\10_appendix.tex', 'source_files/2305.15011\\1_introduction.tex', 'source_files/2305.15011\\2_related_work.tex', 'source_files/2305.15011\\3_dataset.tex', 'source_files/2305.15011\\4_model.tex', 'source_files/2305.15011\\5_experiment.tex', 'source_files/2305.15011\\6_conclusion.tex', 'source_files/2305.15011\\7_limitations.tex', 'source_files/2305.15011\\8_ethics.tex', 'source_files/2305.15011\\emnlp2023.tex', 'source_files/2305.15011\\figures\\gpt4_eval_prompt.tex', 'source_files/2305.15011\\tables\\benchmark_stat.tex', 'source_files/2305.15011\\tables\\data_stat.tex', 'source_files/2305.15011\\tables\\exam.tex', 'source_files/2305.15011\\tables\\experiment_downstream.tex', 'source_files/2305.15011\\tables\\full_result.tex', 'source_files/2305.15011\\tables\\human_eval.tex', 'source_files/2305.15011\\tables\\mono_vs_multi.tex', 'source_files/2305.15011\\tables\\mt_quality.tex', 'source_files/2305.15011\\tables\\response_quality.tex']
# 2/17 tables collected.
# 1/12 figures collected.
#
#
#  25 2305.18459
# ['source_files/2305.18459\\neurips_2023.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 3/11 figures collected.
#
#
#  26 2306.00042
# ['source_files/2306.00042\\main.tex']
# 5/6 tables collected.
# 0/1 figures collected.
#
#
#  27 2306.00398
# ['source_files/2306.00398\\main.tex', 'source_files/2306.00398\\math_commands.tex', 'source_files/2306.00398\\Tex\\appendix.tex', 'source_files/2306.00398\\Tex\\Applications.tex', 'source_files/2306.00398\\Tex\\application_prompt.tex', 'source_files/2306.00398\\Tex\\application_suma.tex', 'source_files/2306.00398\\Tex\\background.tex', 'source_files/2306.00398\\Tex\\conclusion.tex', 'source_files/2306.00398\\Tex\\connection_rl.tex', 'source_files/2306.00398\\Tex\\experiments.tex', 'source_files/2306.00398\\Tex\\intro.tex', 'source_files/2306.00398\\Tex\\method.tex', 'source_files/2306.00398\\Tex\\method2.tex', 'source_files/2306.00398\\Tex\\related.tex', 'source_files/2306.00398\\Tex\\tab\\prompt_example.tex', 'source_files/2306.00398\\Tex\\tab\\prompt_main.tex', 'source_files/2306.00398\\Tex\\tab\\seq_rew.tex', 'source_files/2306.00398\\Tex\\tab\\suma_main.tex', 'source_files/2306.00398\\Tex\\tab\\t5_base_cnn.tex', 'source_files/2306.00398\\Tex\\tab\\tables_rebuttal.tex', 'source_files/2306.00398\\Tex\\tab\\temp_cnn.tex', 'source_files/2306.00398\\Tex\\tab\\traj_cnn.tex', 'source_files/2306.00398\\Tex\\tab\\traj_xsum.tex', 'source_files/2306.00398\\Tex\\tab\\use_r_vs_q.tex', 'source_files/2306.00398\\Tex\\tab\\wo_rew_retrain.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 0/7 figures collected.
#
#
#  28 2306.03580
# ['source_files/2306.03580\\valDiags.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 5/11 figures collected.
#
#
#  29 2306.05288
# ['source_files/2306.05288\\hydrostatic_table.tex', 'source_files/2306.05288\\paper.tex', 'source_files/2306.05288\\square2_conv_div_errors.tex', 'source_files/2306.05288\\square2_conv_jump_errors.tex', 'source_files/2306.05288\\square2_conv_l2_errors_p.tex', 'source_files/2306.05288\\square2_conv_l2_errors_u.tex', 'source_files/2306.05288\\square2_press_rob_conv_p.tex', 'source_files/2306.05288\\square2_press_rob_conv_u.tex', 'source_files/2306.05288\\wannier_conv_div_errors.tex', 'source_files/2306.05288\\wannier_conv_jump_errors.tex', 'source_files/2306.05288\\wannier_conv_l2_errors_u.tex', 'source_files/2306.05288\\wannier_press_rob_conv_u.tex']
# 0/1 tables collected.
# 0/9 figures collected.
#
#
#  30 2306.05534
# ['source_files/2306.05534\\conclusion.tex', 'source_files/2306.05534\\detection.tex', 'source_files/2306.05534\\disclosure.tex', 'source_files/2306.05534\\evaluation-methodology.tex', 'source_files/2306.05534\\evaluation-results.tex', 'source_files/2306.05534\\introduction.tex', 'source_files/2306.05534\\pipeline-results.tex', 'source_files/2306.05534\\prevalence.tex', 'source_files/2306.05534\\relatedwork.tex', 'source_files/2306.05534\\sca-results.tex', 'source_files/2306.05534\\security-blindspots-arxivpp.tex', 'source_files/2306.05534\\threats.tex', 'source_files/2306.05534\\vulnerable-artifacts.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 3/3 figures collected.
#
#
#  31 2306.06304
# ['source_files/2306.06304\\badia_li_martin_2023.tex', 'source_files/2306.06304\\conclusions.tex', 'source_files/2306.06304\\implmt.tex', 'source_files/2306.06304\\intro.tex', 'source_files/2306.06304\\method-forward.tex', 'source_files/2306.06304\\method-inverse.tex', 'source_files/2306.06304\\numexp.tex']
# 0/0 tables collected.
# 1/15 figures collected.
#
#
#  32 2306.08749
# ['source_files/2306.08749\\1_introduction_v1.tex', 'source_files/2306.08749\\2_methods_v1.tex', 'source_files/2306.08749\\3_experimental_design_results_v1.tex', 'source_files/2306.08749\\4_discussion_and_conclusion_v1.tex', 'source_files/2306.08749\\5_supplementary_material_v1.tex', 'source_files/2306.08749\\paper843.tex']
# 1/3 tables collected.
# 1/4 figures collected.
#
#
#  33 2306.10502
# ['source_files/2306.10502\\neurips_2023.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 1/7 figures collected.
#
#
#  34 2306.11375
# ['source_files/2306.11375\\main.tex', 'source_files/2306.11375\\supporting_info.tex']
# 2/5 tables collected.
# 1/4 figures collected.
#
#
#  35 2306.12369
# ['source_files/2306.12369\\main.tex']
# 2/5 tables collected.
# 2/10 figures collected.
#
#
#  36 2307.05330
# ['source_files/2307.05330\\main.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 0/17 figures collected.
#
#
#  37 2307.06077
# ['source_files/2307.06077\\fairness_in_general.tex']
# 0/0 tables collected.
# 0/0 figures collected.
#
#
#  38 2307.13746
# ['source_files/2307.13746\\childgan.tex', 'source_files/2307.13746\\Tables\\exptab1.tex', 'source_files/2307.13746\\Tables\\tab1.tex', 'source_files/2307.13746\\Tables\\tab2.tex', 'source_files/2307.13746\\Tables\\tab3.tex', 'source_files/2307.13746\\Tables\\tab3update.tex', 'source_files/2307.13746\\Tables\\tab4.tex', 'source_files/2307.13746\\Tables\\tab4test.tex']
# 5/11 tables collected.
# 10/20 figures collected.
#
#
#  39 2308.01853
# ['source_files/2308.01853\\main.tex', 'source_files/2308.01853\\tikz\\gaussian_perturbation_ids.tex', 'source_files/2308.01853\\tikz\\gaussian_perturbation_wds.tex', 'source_files/2308.01853\\tikz\\lr_tikz.tex']
# 0/7 tables collected.
# 0/7 figures collected.
#
#
#  40 2308.02599
# ['source_files/2308.02599\\acknowledgements.tex', 'source_files/2308.02599\\header.tex', 'source_files/2308.02599\\macros.tex', 'source_files/2308.02599\\main.tex', 'source_files/2308.02599\\packages.tex', 'source_files/2308.02599\\parts_abstract.tex', 'source_files/2308.02599\\parts_conclusions.tex', 'source_files/2308.02599\\parts_discussion.tex', 'source_files/2308.02599\\parts_intro.tex', 'source_files/2308.02599\\parts_methods.tex', 'source_files/2308.02599\\parts_results.tex']
# 2/6 tables collected.
# 0/10 figures collected.
#
#
#  41 2308.06160
# ['source_files/2308.06160\\neurips_2023.tex', 'source_files/2308.06160\\tables\\ablation_aug_baseline.tex', 'source_files/2308.06160\\tables\\ablation_study.tex', 'source_files/2308.06160\\tables\\all.tex', 'source_files/2308.06160\\tables\\cityscapes.tex', 'source_files/2308.06160\\tables\\cityscapes_class.tex', 'source_files/2308.06160\\tables\\COCO_Ins.tex', 'source_files/2308.06160\\tables\\COCO_pose.tex', 'source_files/2308.06160\\tables\\data.tex', 'source_files/2308.06160\\tables\\deepfashion.tex', 'source_files/2308.06160\\tables\\doamin_generalization.tex', 'source_files/2308.06160\\tables\\KITTI_depth.tex', 'source_files/2308.06160\\tables\\NYU_depth.tex', 'source_files/2308.06160\\tables\\prompts.tex', 'source_files/2308.06160\\tables\\sim_supervised_work.tex', 'source_files/2308.06160\\tables\\VOC.tex', 'source_files/2308.06160\\tables\\zero_shot_and_long_tail.tex', 'source_files/2308.06160\\tables\\zs3.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 0/13 figures collected.
#
#
#  42 2308.09858
# ['source_files/2308.09858\\aaai24.tex']
# 5/6 tables collected.
# 0/4 figures collected.
#
#
#  43 2308.15009
# ['source_files/2308.15009\\main.tex']
# 1/2 tables collected.
# 0/0 figures collected.
#
#
#  44 2309.08066
# ['source_files/2309.08066\\main.tex']
# 13/18 tables collected.
# 4/11 figures collected.
#
#
#  45 2309.08774
# ['source_files/2309.08774\\asplos24-paper-template.tex', 'source_files/2309.08774\\globals.tex', 'source_files/2309.08774\\main.tex', 'source_files/2309.08774\\figures\\gmc-integrator.tex', 'source_files/2309.08774\\gen-specs\\func-example-br-tln-Em-hwtln-lang.tex', 'source_files/2309.08774\\gen-specs\\func-example-br-tln-Nm-hwtln-lang.tex', 'source_files/2309.08774\\gen-specs\\func-example-br-tln-tln-lang.tex', 'source_files/2309.08774\\gen-specs\\lang-cnn-language.tex', 'source_files/2309.08774\\gen-specs\\lang-cnn-relations.tex', 'source_files/2309.08774\\gen-specs\\lang-cnn-types.tex', 'source_files/2309.08774\\gen-specs\\lang-cnn-validation.tex', 'source_files/2309.08774\\gen-specs\\lang-con-intercon-language.tex', 'source_files/2309.08774\\gen-specs\\lang-con-intercon-relations.tex', 'source_files/2309.08774\\gen-specs\\lang-con-intercon-types.tex', 'source_files/2309.08774\\gen-specs\\lang-con-types.tex', 'source_files/2309.08774\\gen-specs\\lang-gmc-tln-language.tex', 'source_files/2309.08774\\gen-specs\\lang-hw-cnn-language.tex', 'source_files/2309.08774\\gen-specs\\lang-hw-cnn-relations.tex', 'source_files/2309.08774\\gen-specs\\lang-hwcnn-relations.tex', 'source_files/2309.08774\\gen-specs\\lang-hwcnn-types.tex', 'source_files/2309.08774\\gen-specs\\lang-hwcon-intercon-language.tex', 'source_files/2309.08774\\gen-specs\\lang-hwcon-intercon-types.tex', 'source_files/2309.08774\\gen-specs\\lang-hwcon-intercon-validation.tex', 'source_files/2309.08774\\gen-specs\\lang-hwtln-language.tex', 'source_files/2309.08774\\gen-specs\\lang-hwtln-relations.tex', 'source_files/2309.08774\\gen-specs\\lang-hwtln-types.tex', 'source_files/2309.08774\\gen-specs\\lang-intercon-obc-language.tex', 'source_files/2309.08774\\gen-specs\\lang-mm-tln-language.tex', 'source_files/2309.08774\\gen-specs\\lang-obc-language.tex', 'source_files/2309.08774\\gen-specs\\lang-obc-relations.tex', 'source_files/2309.08774\\gen-specs\\lang-obc-types.tex', 'source_files/2309.08774\\gen-specs\\lang-ofs-obc-language.tex', 'source_files/2309.08774\\gen-specs\\lang-tln-br-func.tex', 'source_files/2309.08774\\gen-specs\\lang-tln-language.tex', 'source_files/2309.08774\\gen-specs\\lang-tln-relations.tex', 'source_files/2309.08774\\gen-specs\\lang-tln-types.tex', 'source_files/2309.08774\\gen-specs\\lang-tln-validation.tex', 'source_files/2309.08774\\old\\tln-example\\lang-hwtln-language.tex', 'source_files/2309.08774\\old\\tln-example\\lang-tln-br-func.tex', 'source_files/2309.08774\\old\\tln-example\\lang-tln-language.tex', 'source_files/2309.08774\\sections\\abstract.tex', 'source_files/2309.08774\\sections\\acknowledgement.tex', 'source_files/2309.08774\\sections\\conclusion.tex', 'source_files/2309.08774\\sections\\evaluation.tex', 'source_files/2309.08774\\sections\\example-backup.tex', 'source_files/2309.08774\\sections\\example.tex', 'source_files/2309.08774\\sections\\introduction-scratch.tex', 'source_files/2309.08774\\sections\\introduction.tex', 'source_files/2309.08774\\sections\\limitation.tex', 'source_files/2309.08774\\sections\\related.tex', 'source_files/2309.08774\\sections\\tech-cdg.tex', 'source_files/2309.08774\\sections\\tech-generation.tex', 'source_files/2309.08774\\sections\\tech-implementation.tex', 'source_files/2309.08774\\sections\\tech-lang-scratch.tex', 'source_files/2309.08774\\sections\\tech-lang.tex', 'source_files/2309.08774\\sections\\tech-validation.tex']
# 0/7 tables collected.
# 3/29 figures collected.
#
#
#  46 2309.08880
# ['source_files/2309.08880\\main.tex']
# 0/0 tables collected.
# 4/10 figures collected.
#
#
#  47 2309.10916
# ['source_files/2309.10916\\acl2023.tex']
# 11/13 tables collected.
# 5/8 figures collected.
#
#
#  48 2309.11592
# ['source_files/2309.11592\\body.tex', 'source_files/2309.11592\\main.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 1/3 figures collected.
#
#
#  49 2309.11600
# ['source_files/2309.11600\\body.tex', 'source_files/2309.11600\\main.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 2/3 figures collected.
#
#
#  50 2310.00839
# ['source_files/2310.00839\\main.tex']
# 2/2 tables collected.
# 0/21 figures collected.
#
#
#  51 2310.02996
# ['source_files/2310.02996\\arXiv-new.tex']
# 1/1 tables collected.
# 2/4 figures collected.
#
#
#  52 2310.03925
# ['source_files/2310.03925\\main_ieee.tex', 'source_files/2310.03925\\insert\\alg_mtl_sgd.tex', 'source_files/2310.03925\\insert\\alg_warping.tex', 'source_files/2310.03925\\insert\\fig_hard_soft.tex', 'source_files/2310.03925\\insert\\fig_path_viz.tex', 'source_files/2310.03925\\insert\\fig_resnet_1d.tex', 'source_files/2310.03925\\insert\\fig_resnet_2d.tex', 'source_files/2310.03925\\insert\\fig_resnet_2d_use.tex', 'source_files/2310.03925\\insert\\fig_resnet_rep.tex', 'source_files/2310.03925\\insert\\fig_toy.tex', 'source_files/2310.03925\\insert\\tab_ucr_data.tex', 'source_files/2310.03925\\insert\\tab_ucr_task.tex', 'source_files/2310.03925\\insert\\tab_visa_acc.tex', 'source_files/2310.03925\\section\\abstract.tex', 'source_files/2310.03925\\section\\author.tex', 'source_files/2310.03925\\section\\conclusion.tex', 'source_files/2310.03925\\section\\experiment.tex', 'source_files/2310.03925\\section\\introduction.tex', 'source_files/2310.03925\\section\\method.tex', 'source_files/2310.03925\\section\\preamble.tex', 'source_files/2310.03925\\section\\related.tex']
# 0/4 tables collected.
# 0/7 figures collected.
#
#
#  53 2310.04373
# ['source_files/2310.04373\\crlhf_iclr.tex', 'source_files/2310.04373\\imports.tex', 'source_files/2310.04373\\m.macros.tex', 'source_files/2310.04373\\m.symbols.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 0/12 figures collected.
#
#
#  54 2310.04490
# ['source_files/2310.04490\\Diffusion.tex']
# 0/1 tables collected.
# 0/2 figures collected.
#
#
#  55 2310.04567
# ['source_files/2310.04567\\main.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 1/4 figures collected.
#
#
#  56 2310.04570
# ['source_files/2310.04570\\main.tex', 'source_files/2310.04570\\math_commands.tex', 'source_files/2310.04570\\tex\\abstract.tex', 'source_files/2310.04570\\tex\\approach.tex', 'source_files/2310.04570\\tex\\conclusions.tex', 'source_files/2310.04570\\tex\\experiments.tex', 'source_files/2310.04570\\tex\\introduction.tex', 'source_files/2310.04570\\tex\\relatedworks.tex']
# 1/2 tables collected.
# 1/4 figures collected.
#
#
#  57 2310.04898
# ['source_files/2310.04898\\coding.tex', 'source_files/2310.04898\\elsarticle.tex', 'source_files/2310.04898\\main.tex', 'source_files/2310.04898\\sections\\01_introduction.tex', 'source_files/2310.04898\\sections\\02_verifiable_share.tex', 'source_files/2310.04898\\sections\\03_proactive.tex', 'source_files/2310.04898\\sections\\04_consensus.tex', 'source_files/2310.04898\\sections\\05_frost.tex', 'source_files/2310.04898\\sections\\background.tex', 'source_files/2310.04898\\sections\\blockchain.tex']
# 1/2 tables collected.
# 4/8 figures collected.
#
#
#  58 2310.04923
# ['source_files/2310.04923\\main.tex']
# 5/11 tables collected.
# 14/18 figures collected.
#
#
#  59 2310.05189
# ['source_files/2310.05189\\main.tex']
# 0/0 tables collected.
# 0/0 figures collected.
#
#
#  60 2310.05242
# ['source_files/2310.05242\\LLM_radoncphys.tex']
# 12/17 tables collected.
# 5/18 figures collected.
#
#
#  61 2310.05255
# ['source_files/2310.05255\\main.tex', 'source_files/2310.05255\\src\\Abstract.tex', 'source_files/2310.05255\\src\\Background.tex', 'source_files/2310.05255\\src\\conclusion-future-work.tex', 'source_files/2310.05255\\src\\Datasets.tex', 'source_files/2310.05255\\src\\Experiments-1.tex', 'source_files/2310.05255\\src\\Experiments-2.tex', 'source_files/2310.05255\\src\\Experiments-3.tex', 'source_files/2310.05255\\src\\Experiments-4.tex', 'source_files/2310.05255\\src\\Experiments.tex', 'source_files/2310.05255\\src\\Introduction.tex', 'source_files/2310.05255\\src\\Keywords.tex', 'source_files/2310.05255\\src\\Method-image-classification.tex', 'source_files/2310.05255\\src\\Method-image-segmentation.tex', 'source_files/2310.05255\\src\\Method.tex', 'source_files/2310.05255\\src\\Related-Work.tex', 'source_files/2310.05255\\src\\title-and-authors.tex']
# 5/6 tables collected.
# 5/8 figures collected.
#
#
#  62 2310.05371
# ['source_files/2310.05371\\main.tex', 'source_files/2310.05371\\old_relatedwork.tex', 'source_files/2310.05371\\table.tex']
# 1/1 tables collected.
# 2/3 figures collected.
#
#
#  63 2310.05629
# ['source_files/2310.05629\\Template.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 1/4 figures collected.
#
#
#  64 2310.05732
# ['source_files/2310.05732\\99-appendix.tex', 'source_files/2310.05732\\995-appendix-totalcompletiontime.tex', 'source_files/2310.05732\\main.tex']
# 0/0 tables collected.
# 0/4 figures collected.
#
#
#  65 2310.05813
# ['source_files/2310.05813\\main.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 1/2 figures collected.
#
#
#  66 2310.05863
# ['source_files/2310.05863\\iclr2024_conference.tex', 'source_files/2310.05863\\math_commands.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 4/12 figures collected.
#
#
#  67 2310.05936
# ['source_files/2310.05936\\conclusion.tex', 'source_files/2310.05936\\discussion.tex', 'source_files/2310.05936\\intro.tex', 'source_files/2310.05936\\lessons.tex', 'source_files/2310.05936\\main.tex', 'source_files/2310.05936\\pram.tex', 'source_files/2310.05936\\pramws3.tex', 'source_files/2310.05936\\relatedWork.tex']
# 0/0 tables collected.
# 0/0 figures collected.
#
#
#  68 2310.05939
# ['source_files/2310.05939\\ijcai23.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 4/4 figures collected.
#
#
#  69 2310.05942
# ['source_files/2310.05942\\TMAS-FN.tex']
# 0/0 tables collected.
# 9/9 figures collected.
#
#
#  70 2310.05947
# ['source_files/2310.05947\\imagetattack20230902.tex']
# 0/0 tables collected.
# 3/3 figures collected.
#
#
#  71 2310.05984
# ['source_files/2310.05984\\paper.tex']
# 1/3 tables collected.
# 2/4 figures collected.
#
#
#  72 2310.05993
# ['source_files/2310.05993\\sn-article.tex', 'source_files/2310.05993\\sn-sample-bib.tex']
# 0/3 tables collected.
# 1/2 figures collected.
#
#
#  73 2310.05997
# ['source_files/2310.05997\\elsarticle-template-num-names.tex', 'source_files/2310.05997\\elsarticle-template-num.tex', 'source_files/2310.05997\\paper-arxiv.tex', 'source_files/2310.05997\\supp_Mat.tex', 'source_files/2310.05997\\doc\\elsdoc.tex']
# 18/22 tables collected.
# 4/34 figures collected.
#
#
#  74 2310.05998
# ['source_files/2310.05998\\main.tex']
# 0/1 tables collected.
# 2/4 figures collected.
#
#
#  75 2310.06001
# ['source_files/2310.06001\\JCAE_IntroControle.tex', 'source_files/2310.06001\\sbaconf.tex']
# 12/14 tables collected.
# 8/13 figures collected.
#
#
#  76 2310.06002
# ['source_files/2310.06002\\main.tex']
# 0/0 tables collected.
# 8/9 figures collected.
#
#
#  77 2310.06047
# ['source_files/2310.06047\\main.tex']
# 0/1 tables collected.
# 0/2 figures collected.
#
#
#  78 2310.06061
# ['source_files/2310.06061\\conclusion.tex', 'source_files/2310.06061\\introduction.tex', 'source_files/2310.06061\\main.tex', 'source_files/2310.06061\\methodology.tex', 'source_files/2310.06061\\relatedwork.tex', 'source_files/2310.06061\\results.tex']
# 4/4 tables collected.
# 0/3 figures collected.
#
#
#  79 2310.06068
# ['source_files/2310.06068\\templateArxiv.tex']
# 3/4 tables collected.
# 5/12 figures collected.
#
#
#  80 2310.06080
# ['source_files/2310.06080\\pneumonia.tex']
# 0/11 tables collected.
# 0/23 figures collected.
#
#
#  81 2310.06083
# ['source_files/2310.06083\\sn-article.tex']
# 0/0 tables collected.
# 2/3 figures collected.
#
#
#  82 2310.06100
# ['source_files/2310.06100\\main.tex', 'source_files/2310.06100\\math_commands.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 3/16 figures collected.
#
#
#  83 2310.06103
# ['source_files/2310.06103\\bibliography.tex', 'source_files/2310.06103\\paper.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 0/3 figures collected.
#
#
#  84 2310.06111
# ['source_files/2310.06111\\abstract.tex', 'source_files/2310.06111\\conclusion.tex', 'source_files/2310.06111\\ethics.tex', 'source_files/2310.06111\\eval.tex', 'source_files/2310.06111\\intro.tex', 'source_files/2310.06111\\limitations.tex', 'source_files/2310.06111\\overview.tex', 'source_files/2310.06111\\paper.tex', 'source_files/2310.06111\\prompts-appendix.tex', 'source_files/2310.06111\\prompts.tex', 'source_files/2310.06111\\related.tex', 'source_files/2310.06111\\user-study.tex']
# 1/3 tables collected.
# 1/2 figures collected.
#
#
#  85 2310.06113
# ['source_files/2310.06113\\arxiv_style.tex', 'source_files/2310.06113\\ayush.tex', 'source_files/2310.06113\\paper.tex', 'source_files/2310.06113\\project_macros.tex', 'source_files/2310.06113\\todonotes.tex', 'source_files/2310.06113\\sections\\abstract.tex', 'source_files/2310.06113\\sections\\app_C_pi.tex', 'source_files/2310.06113\\sections\\app_examples.tex', 'source_files/2310.06113\\sections\\app_generative.tex', 'source_files/2310.06113\\sections\\app_infinite_policy_class.tex', 'source_files/2310.06113\\sections\\app_lower_bound.tex', 'source_files/2310.06113\\sections\\app_lower_bound_proof.tex', 'source_files/2310.06113\\sections\\app_technical_tools.tex', 'source_files/2310.06113\\sections\\app_ub_proof.tex', 'source_files/2310.06113\\sections\\C_pi.tex', 'source_files/2310.06113\\sections\\discussion.tex', 'source_files/2310.06113\\sections\\generative_model.tex', 'source_files/2310.06113\\sections\\introduction.tex', 'source_files/2310.06113\\sections\\lower-bound.tex', 'source_files/2310.06113\\sections\\minimax-complexity.tex', 'source_files/2310.06113\\sections\\old.tex', 'source_files/2310.06113\\sections\\old_upper_bound_proof_sketch.tex', 'source_files/2310.06113\\sections\\online_lower_bound.tex', 'source_files/2310.06113\\sections\\online_upper_bound.tex', 'source_files/2310.06113\\sections\\other_measures.tex', 'source_files/2310.06113\\sections\\related_works.tex', 'source_files/2310.06113\\sections\\setup.tex', 'source_files/2310.06113\\sections\\strong_feedback.tex', 'source_files/2310.06113\\sections\\structural.tex']
# 0/0 tables collected.
# 0/2 figures collected.
#
#
#  86 2310.06122
# ['source_files/2310.06122\\samplepaper.tex']
# 0/0 tables collected.
# 3/3 figures collected.
#
#
#  87 2310.06123
# ['source_files/2310.06123\\appendix.tex', 'source_files/2310.06123\\conclusion.tex', 'source_files/2310.06123\\experiment.tex', 'source_files/2310.06123\\introduction.tex', 'source_files/2310.06123\\main.tex', 'source_files/2310.06123\\math_commands.tex', 'source_files/2310.06123\\method.tex', 'source_files/2310.06123\\related_work.tex', 'source_files/2310.06123\\figures\\ablation.tex', 'source_files/2310.06123\\figures\\fl_structure.tex', 'source_files/2310.06123\\figures\\prompt_embs.tex', 'source_files/2310.06123\\figures\\tpg.tex', 'source_files/2310.06123\\tables\\main_table.tex', 'source_files/2310.06123\\tables\\table_ncls.tex', 'source_files/2310.06123\\tables\\table_other_cls.tex', 'source_files/2310.06123\\tables\\table_other_dataset.tex', 'source_files/2310.06123\\tables\\table_transfer.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 0/4 figures collected.
#
#
#  88 2310.06125
# ['source_files/2310.06125\\complexity_table.tex', 'source_files/2310.06125\\content.tex', 'source_files/2310.06125\\final_table.tex', 'source_files/2310.06125\\includes.tex', 'source_files/2310.06125\\Template_Blind.tex']
# 0/2 tables collected.
# 0/7 figures collected.
#
#
#  89 2310.06138
# ['source_files/2310.06138\\mm23.tex', 'source_files/2310.06138\\tex\\1abstract.tex', 'source_files/2310.06138\\tex\\2introduction.tex', 'source_files/2310.06138\\tex\\3relatedworks.tex', 'source_files/2310.06138\\tex\\4method.tex', 'source_files/2310.06138\\tex\\5experiments.tex', 'source_files/2310.06138\\tex\\6conclusion.tex', 'source_files/2310.06138\\tex\\appendix.tex', 'source_files/2310.06138\\tex\\drafts.tex']
# 3/6 tables collected.
# 0/4 figures collected.
#
#
#  90 2310.06139
# ['source_files/2310.06139\\LinAlg.tex']
# 0/0 tables collected.
# 0/0 figures collected.
#
#
#  91 2310.06148
# ['source_files/2310.06148\\arxiv.tex']
# 0/2 tables collected.
# 0/6 figures collected.
#
#
#  92 2310.06153
# ['source_files/2310.06153\\root.tex']
# 0/0 tables collected.
# 0/6 figures collected.
#
#
#  93 2310.06159
# ['source_files/2310.06159\\abstract.tex', 'source_files/2310.06159\\authorsample.tex', 'source_files/2310.06159\\conclusion.tex', 'source_files/2310.06159\\introduction.tex', 'source_files/2310.06159\\matrix.tex', 'source_files/2310.06159\\numerical.tex', 'source_files/2310.06159\\overparam.tex', 'source_files/2310.06159\\references.tex', 'source_files/2310.06159\\ScaledGD_monograph.tex', 'source_files/2310.06159\\tensor.tex']
# 2/4 tables collected.
# 1/6 figures collected.
#
#
#  94 2310.06160
# ['source_files/2310.06160\\main.tex', 'source_files/2310.06160\\doc\\elsdoc.tex']
# 0/0 tables collected.
# 2/9 figures collected.
#
#
#  95 2310.06161
# ['source_files/2310.06161\\add-expts.tex', 'source_files/2310.06161\\CMI.tex', 'source_files/2310.06161\\discussion.tex', 'source_files/2310.06161\\exp-bios.tex', 'source_files/2310.06161\\exp-ood.tex', 'source_files/2310.06161\\exp-results.tex', 'source_files/2310.06161\\exp-sb.tex', 'source_files/2310.06161\\exp-subgroups.tex', 'source_files/2310.06161\\gaussian.tex', 'source_files/2310.06161\\intro_new.tex', 'source_files/2310.06161\\invariance.tex', 'source_files/2310.06161\\macros.tex', 'source_files/2310.06161\\main.tex', 'source_files/2310.06161\\motivating-exps.tex', 'source_files/2310.06161\\rel-work.tex', 'source_files/2310.06161\\th_res.tex', 'source_files/2310.06161\\appendix\\exp-bios.tex', 'source_files/2310.06161\\appendix\\exp-ood.tex', 'source_files/2310.06161\\appendix\\exp-sb.tex', 'source_files/2310.06161\\appendix\\exp-settings.tex', 'source_files/2310.06161\\appendix\\exp-subgroup.tex', 'source_files/2310.06161\\appendix\\proofs.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 2/5 figures collected.
#
#
#  96 2310.06164
# ['source_files/2310.06164\\main.tex']
# 3/3 tables collected.
# 4/4 figures collected.
#
#
#  97 2310.06170
# ['source_files/2310.06170\\main.tex', 'source_files/2310.06170\\split_phase_diagram.tex', 'source_files/2310.06170\\split_phase_T.tex', 'source_files/2310.06170\\split_phase_xfrm_diagram.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 0/11 figures collected.
#
#
#  98 2310.06177
# ['source_files/2310.06177\\main.tex', 'source_files/2310.06177\\math_commands.tex', 'source_files/2310.06177\\appendix\\appendix.tex', 'source_files/2310.06177\\content\\abstract.tex', 'source_files/2310.06177\\content\\acknowledgements.tex', 'source_files/2310.06177\\content\\conclusion.tex', 'source_files/2310.06177\\content\\experiments.tex', 'source_files/2310.06177\\content\\introduction.tex', 'source_files/2310.06177\\content\\methods.tex', 'source_files/2310.06177\\content\\related_work.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 2/3 figures collected.
#
#
#  99 2310.06178
# ['source_files/2310.06178\\msgemm_sp.tex', 'source_files/2310.06178\\samplepaper.tex']
# 0/0 tables collected.
# 2/3 figures collected.
#
#
#  100 2310.06194
# ['source_files/2310.06194\\Appendix.tex', 'source_files/2310.06194\\Introduction.tex', 'source_files/2310.06194\\Prob_Results.tex', 'source_files/2310.06194\\Proofs.tex', 'source_files/2310.06194\\root.tex', 'source_files/2310.06194\\Sim.tex']
# 0/0 tables collected.
# 2/2 figures collected.
#
#
#  101 2310.06205
# ['source_files/2310.06205\\analysis.tex', 'source_files/2310.06205\\appendix.tex', 'source_files/2310.06205\\conclusion.tex', 'source_files/2310.06205\\formulation.tex', 'source_files/2310.06205\\intro.tex', 'source_files/2310.06205\\main.tex', 'source_files/2310.06205\\math_commands.tex', 'source_files/2310.06205\\numerical.tex', 'source_files/2310.06205\\related.tex', 'source_files/2310.06205\\training_details.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 1/18 figures collected.
#
#
#  102 2310.06210
# ['source_files/2310.06210\\0_abstract.tex', 'source_files/2310.06210\\1_intro.tex', 'source_files/2310.06210\\2_related-work.tex', 'source_files/2310.06210\\3_methods.tex', 'source_files/2310.06210\\4_experiments.tex', 'source_files/2310.06210\\5_results.tex', 'source_files/2310.06210\\6_conclusion.tex', 'source_files/2310.06210\\main.tex']
# 2/2 tables collected.
# 1/8 figures collected.
#
#
#  103 2310.06211
# ['source_files/2310.06211\\main.tex']
# 0/1 tables collected.
# 0/1 figures collected.
#
#
#  104 2310.06219
# ['source_files/2310.06219\\main.tex']
# 0/1 tables collected.
# 3/3 figures collected.
#
#
#  105 2310.06226
# ['source_files/2310.06226\\conclusion.tex', 'source_files/2310.06226\\defs.tex', 'source_files/2310.06226\\experiments.tex', 'source_files/2310.06226\\humaoid_related_work.tex', 'source_files/2310.06226\\Introduction.tex', 'source_files/2310.06226\\main.tex', 'source_files/2310.06226\\Method.tex', 'source_files/2310.06226\\related_work.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 0/5 figures collected.
#
#
#  106 2310.06227
# ['source_files/2310.06227\\1.5_Preliminaries.tex', 'source_files/2310.06227\\2_Relatedworks.tex', 'source_files/2310.06227\\3_experiment.tex', 'source_files/2310.06227\\4_results.tex', 'source_files/2310.06227\\5_discussion.tex', 'source_files/2310.06227\\main.tex']
# 1/3 tables collected.
# 2/4 figures collected.
#
#
#  107 2310.06231
# ['source_files/2310.06231\\ALAPP_Tran.tex', 'source_files/2310.06231\\centralized.tex', 'source_files/2310.06231\\conclusion.tex', 'source_files/2310.06231\\Distributed.tex', 'source_files/2310.06231\\introduction.tex', 'source_files/2310.06231\\main.tex', 'source_files/2310.06231\\MPIMarketMechDesign.tex', 'source_files/2310.06231\\multipleStepSimultaneous.tex', 'source_files/2310.06231\\notation.tex', 'source_files/2310.06231\\numerical.tex', 'source_files/2310.06231\\VCG.tex']
# 1/5 tables collected.
# 7/21 figures collected.
#
#
#  108 2310.06232
# ['source_files/2310.06232\\neurips_2023.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 0/4 figures collected.
#
#
#  109 2310.06233
# ['source_files/2310.06233\\tensor_completion.tex']
# 1/3 tables collected.
# 2/9 figures collected.
#
#
#  110 2310.06241
# ['source_files/2310.06241\\Document.tex']
# 3/3 tables collected.
# 4/11 figures collected.
#
#
#  111 2310.06245
# ['source_files/2310.06245\\ms.tex']
# 10/10 tables collected.
# 1/11 figures collected.
#
#
#  112 2310.06249
# ['source_files/2310.06249\\root.tex', 'source_files/2310.06249\\meta\\usercmds.tex']
# 4/4 tables collected.
# 9/13 figures collected.
#
#
#  113 2310.06251
# ['source_files/2310.06251\\dl-tutorial.tex']
# 0/0 tables collected.
# 0/1 figures collected.
#
#
#  114 2310.06254
# ['source_files/2310.06254\\ms.tex']
# 5/13 tables collected.
# 3/3 figures collected.
#
#
#  115 2310.06260
# ['source_files/2310.06260\\template.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 3/3 figures collected.
#
#
#  116 2310.06269
# ['source_files/2310.06269\\abstract.tex', 'source_files/2310.06269\\analysis.tex', 'source_files/2310.06269\\conclusion.tex', 'source_files/2310.06269\\consent-and-data-collection.tex', 'source_files/2310.06269\\demographics.tex', 'source_files/2310.06269\\dicussion.tex', 'source_files/2310.06269\\in-class-activity.tex', 'source_files/2310.06269\\introduction.tex', 'source_files/2310.06269\\main_FAccT.tex', 'source_files/2310.06269\\methodology.tex', 'source_files/2310.06269\\post-activity-questionnaire.tex', 'source_files/2310.06269\\pre-class-questionnaire.tex', 'source_files/2310.06269\\preamble.tex', 'source_files/2310.06269\\queue-snapshot.tex', 'source_files/2310.06269\\slides.tex', 'source_files/2310.06269\\tests.tex', 'source_files/2310.06269\\usability-ratings.tex']
# 2/2 tables collected.
# 0/8 figures collected.
#
#
#  117 2310.06271
# ['source_files/2310.06271\\emnlp2023.tex']
# 3/10 tables collected.
# 1/6 figures collected.
#
#
#  118 2310.06296
# ['source_files/2310.06296\\10_discussion.tex', 'source_files/2310.06296\\11_conclusion.tex', 'source_files/2310.06296\\12_appendix.tex', 'source_files/2310.06296\\1_introduction.tex', 'source_files/2310.06296\\2_background.tex', 'source_files/2310.06296\\4_curve_Exploration-Designspace.tex', 'source_files/2310.06296\\6_exp-protocol.tex', 'source_files/2310.06296\\7_exp-results.tex', 'source_files/2310.06296\\DONOT-use-01_abstract.tex', 'source_files/2310.06296\\main.tex']
# 2/6 tables collected.
# 4/6 figures collected.
#
#
#  119 2310.06301
# ['source_files/2310.06301\\math_commands.tex', 'source_files/2310.06301\\slttms.tex']
# 6/9 tables collected.
# 9/29 figures collected.
#
#
#  120 2310.06307
# ['source_files/2310.06307\\01_abstract.tex', 'source_files/2310.06307\\10_discussion.tex', 'source_files/2310.06307\\11_conclusion.tex', 'source_files/2310.06307\\1_introduction.tex', 'source_files/2310.06307\\2_background.tex', 'source_files/2310.06307\\4_curve_exploration-designspace.tex', 'source_files/2310.06307\\6_exp-protocol.tex', 'source_files/2310.06307\\7_exp-results.tex', 'source_files/2310.06307\\8_exp2protocol.tex', 'source_files/2310.06307\\9_exp2results.tex', 'source_files/2310.06307\\main.tex']
# 0/0 tables collected.
# 3/6 figures collected.
#
#
#  121 2310.06308
# ['source_files/2310.06308\\paper.tex']
# 0/0 tables collected.
# 1/4 figures collected.
#
#
#  122 2310.06309
# ['source_files/2310.06309\\sample-authordraft.tex', 'source_files/2310.06309\\sample-lualatex.tex', 'source_files/2310.06309\\sample-sigconf-i13n.tex', 'source_files/2310.06309\\sample-sigconf.tex', 'source_files/2310.06309\\sample-xelatex.tex']
# 5/9 tables collected.
# 2/8 figures collected.
#
#
#  123 2310.06322
# ['source_files/2310.06322\\conference_101719.tex']
# 0/2 tables collected.
# 0/3 figures collected.
#
#
#  124 2310.06337
# ['source_files/2310.06337\\main.tex']
# 1/1 tables collected.
# 4/5 figures collected.
#
#
#  125 2310.06349
# ['source_files/2310.06349\\main.tex']
# 0/0 tables collected.
# 4/4 figures collected.
#
#
#  126 2310.06362
# ['source_files/2310.06362\\emnlp2023.tex', 'source_files/2310.06362\\table\\ablation.tex', 'source_files/2310.06362\\table\\full_exp.tex', 'source_files/2310.06362\\table\\main_exp.tex']
# 0/6 tables collected.
# 0/4 figures collected.
#
#
#  127 2310.06366
# ['source_files/2310.06366\\IoT-31391-2023.tex', 'source_files/2310.06366\\notation.tex']
# 1/2 tables collected.
# 4/10 figures collected.
#
#
#  128 2310.06368
# ['source_files/2310.06368\\main.tex', 'source_files/2310.06368\\a_figures\\quat_ade.tex', 'source_files/2310.06368\\a_figures\\quat_more.tex', 'source_files/2310.06368\\a_figures\\quat_more2.tex', 'source_files/2310.06368\\a_sections\\appendix.tex', 'source_files/2310.06368\\a_tables\\abl_con.tex', 'source_files/2310.06368\\a_tables\\abl_intra.tex', 'source_files/2310.06368\\a_tables\\abl_lr.tex', 'source_files/2310.06368\\a_tables\\abl_lr_10-1.tex', 'source_files/2310.06368\\a_tables\\abl_reg.tex', 'source_files/2310.06368\\a_tables\\abl_same_magnitude.tex', 'source_files/2310.06368\\a_tables\\abl_tau.tex', 'source_files/2310.06368\\a_tables\\A_corrected.tex', 'source_files/2310.06368\\a_tables\\compareofbackbone.tex', 'source_files/2310.06368\\a_tables\\disjoint.tex', 'source_files/2310.06368\\a_tables\\MicroSeg_choice_of_K.tex', 'source_files/2310.06368\\a_tables\\PL_Lint.tex', 'source_files/2310.06368\\a_tables\\resnet.tex', 'source_files/2310.06368\\a_tables\\vocwithclass.tex', 'source_files/2310.06368\\figures\\comparison.tex', 'source_files/2310.06368\\figures\\contrastive.tex', 'source_files/2310.06368\\figures\\diversity.tex', 'source_files/2310.06368\\figures\\fig1_PMM.tex', 'source_files/2310.06368\\figures\\Flexible_freeze_overview.tex', 'source_files/2310.06368\\figures\\visualization.tex', 'source_files/2310.06368\\sections\\0_abstract.tex', 'source_files/2310.06368\\sections\\1_introduction-gao.tex', 'source_files/2310.06368\\sections\\2_related_work.tex', 'source_files/2310.06368\\sections\\3_method.tex', 'source_files/2310.06368\\sections\\4_experiment.tex', 'source_files/2310.06368\\sections\\5_conclusion.tex', 'source_files/2310.06368\\tables\\ablation.tex', 'source_files/2310.06368\\tables\\ablation_proposal_N.tex', 'source_files/2310.06368\\tables\\ADE.tex', 'source_files/2310.06368\\tables\\detailed_ablation.tex', 'source_files/2310.06368\\tables\\expandion.tex', 'source_files/2310.06368\\tables\\ourmethod_M.tex', 'source_files/2310.06368\\tables\\VOC.tex']
# 0/21 tables collected.
# 1/9 figures collected.
#
#
#  129 2310.06369
# ['source_files/2310.06369\\appendix.tex', 'source_files/2310.06369\\arxiv_GATE.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 6/8 figures collected.
#
#
#  130 2310.06385
# ['source_files/2310.06385\\main.tex']
# 0/3 tables collected.
# 4/6 figures collected.
#
#
#  131 2310.06390
# ['source_files/2310.06390\\emnlp2023.tex']
# 7/10 tables collected.
# 2/3 figures collected.
#
#
#  132 2310.06393
# ['source_files/2310.06393\\acronyms.tex', 'source_files/2310.06393\\figures.tex', 'source_files/2310.06393\\glossary.tex', 'source_files/2310.06393\\main_arxiv.tex', 'source_files/2310.06393\\tables.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 0/5 figures collected.
#
#
#  133 2310.06399
# ['source_files/2310.06399\\neurips_data_2023.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 0/16 figures collected.
#
#
#  134 2310.06412
# ...
# 9/13 tables collected.
# 2/5 figures collected.
#
#
#  1681 2209.06470
# ['source_files/2209.06470\\acl.tex']
# 4/10 tables collected.
# 5/12 figures collected.
#
#
#  1682 2209.06478
# ['source_files/2209.06478\\main.tex', 'source_files/2209.06478\\src\\00_abstract.tex', 'source_files/2209.06478\\src\\00_acronyms.tex', 'source_files/2209.06478\\src\\00_concepts_and_keywords.tex', 'source_files/2209.06478\\src\\01_introduction.tex', 'source_files/2209.06478\\src\\02_background.tex', 'source_files/2209.06478\\src\\03_methodology.tex', 'source_files/2209.06478\\src\\04_experiments.tex', 'source_files/2209.06478\\src\\05_related_work.tex', 'source_files/2209.06478\\src\\06_conclusions.tex', 'source_files/2209.06478\\src\\07_acknowledgments.tex']
# 1/1 tables collected.
# 3/4 figures collected.
#
#
#  1683 2209.06495
# ['source_files/2209.06495\\acsa-scn-07.tex', 'source_files/2209.06495\\Self‐organizing life cycle management of mobile ad hoc networks\\acsa-scn-07.tex']
# 0/0 tables collected.
# 7/14 figures collected.
#
#
#  1684 2209.06525
# ['source_files/2209.06525\\bare_conf.tex']
# 5/7 tables collected.
# 0/3 figures collected.
#
#
#  1685 2209.06546
# ['source_files/2209.06546\\DocuByRefine.tex', 'source_files/2209.06546\\macros.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 2/2 figures collected.
#
#
#  1686 2209.06553
# ['source_files/2209.06553\\main.tex', 'source_files/2209.06553\\Collaborative SQL-Injections Detection System with Machine Learning\\main.tex']
# 0/0 tables collected.
# 4/8 figures collected.
#
#
#  1687 2209.06556
# ['source_files/2209.06556\\0-Wei-SCITEPRESS.tex', 'source_files/2209.06556\\1_intro.tex', 'source_files/2209.06556\\2_related.tex', 'source_files/2209.06556\\3_prelim.tex', 'source_files/2209.06556\\4_description.tex', 'source_files/2209.06556\\5_analysis.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 0/0 figures collected.
#
#
#  1688 2209.06557
# ['source_files/2209.06557\\0_PP_keystroke.tex', 'source_files/2209.06557\\1_intro.tex', 'source_files/2209.06557\\2_related.tex', 'source_files/2209.06557\\3_CA_without_priv.tex', 'source_files/2209.06557\\4_preliminaries.tex', 'source_files/2209.06557\\5_HE-contiouos.tex', 'source_files/2209.06557\\7_analysis.tex', 'source_files/2209.06557\\8_conclusion.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 0/1 figures collected.
#
#
#  1689 2209.06569
# ['source_files/2209.06569\\template.tex']
# 0/0 tables collected.
# 0/1 figures collected.
#
#
#  1690 2209.06570
# ['source_files/2209.06570\\00_MTL_properties_survey.tex', 'source_files/2209.06570\\chapters\\001_Reviews.tex', 'source_files/2209.06570\\chapters\\01_introduction.tex', 'source_files/2209.06570\\chapters\\02_background.tex', 'source_files/2209.06570\\chapters\\03_rw.tex', 'source_files/2209.06570\\chapters\\04_rqs.tex', 'source_files/2209.06570\\chapters\\05_variables.tex', 'source_files/2209.06570\\chapters\\06_subjects.tex', 'source_files/2209.06570\\chapters\\07_execution_plan.tex', 'source_files/2209.06570\\chapters\\08_analysis_plan.tex', 'source_files/2209.06570\\chapters\\09_threats.tex', 'source_files/2209.06570\\chapters\\10_survey_plan.tex', 'source_files/2209.06570\\chapters\\a_variables.tex']
# 0/3 tables collected.
# 1/2 figures collected.
#
#
#  1691 2209.06582
# ['source_files/2209.06582\\sep.tex']
# Document header could not be identified.
# 0/0 tables collected.
# 0/6 figures collected.
#
#
#  1692 2209.06584
# ['source_files/2209.06584\\01abstract.tex', 'source_files/2209.06584\\02introduction.tex', 'source_files/2209.06584\\03related_work.tex', 'source_files/2209.06584\\04proposed_solution.tex', 'source_files/2209.06584\\05experimentation.tex', 'source_files/2209.06584\\06conclusion.tex', 'source_files/2209.06584\\07acknowledgements.tex', 'source_files/2209.06584\\architectural_details.tex', 'source_files/2209.06584\\egpaper.tex', 'source_files/2209.06584\\egrebuttal.tex', 'source_files/2209.06584\\supplementary.tex']
# 5/9 tables collected.
# 6/19 figures collected.
#
#
#  1693 2209.06588
# ['source_files/2209.06588\\main.tex', 'source_files/2209.06588\\figs\\collab_msckf.tex', 'source_files/2209.06588\\figs\\collab_slam.tex', 'source_files/2209.06588\\figs\\corner_histogram.tex', 'source_files/2209.06588\\figs\\datasets.tex', 'source_files/2209.06588\\figs\\eyecatcher.tex', 'source_files/2209.06588\\figs\\method.tex', 'source_files/2209.06588\\figs\\tracks_calib_uncalib.tex', 'source_files/2209.06588\\figs\\trajectories_thermal.tex', 'source_files/2209.06588\\sections\\00_abstract.tex', 'source_files/2209.06588\\sections\\01_intro.tex', 'source_files/2209.06588\\sections\\02_related.tex', 'source_files/2209.06588\\sections\\03_method.tex', 'source_files/2209.06588\\sections\\04_experiments.tex', 'source_files/2209.06588\\sections\\05_conclusion.tex', 'source_files/2209.06588\\sections\\macros.tex', 'source_files/2209.06588\\tables\\tab_communication_data_usage.tex', 'source_files/2209.06588\\tables\\tab_covins_comparison.tex', 'source_files/2209.06588\\tables\\tab_related_work.tex', 'source_files/2209.06588\\tables\\tab_thermal_results.tex', 'source_files/2209.06588\\tables\\tab_time_eval.tex', 'source_files/2209.06588\\tables\\tab_visual_results.tex']
# 5/6 tables collected.
# 0/8 figures collected.
#
#
#  1694 2209.06612
# ['source_files/2209.06612\\acl_latex.tex']
# 7/7 tables collected.
# 7/10 figures collected.
#
#
#  1695 2209.06622
# ['source_files/2209.06622\\my.tex']
# 1/2 tables collected.
# 0/10 figures collected.
#
#
#  1696 2209.06629
# ['source_files/2209.06629\\ECCV.tex']
# 4/5 tables collected.
# 2/2 figures collected.
#
#
#  1697 2209.06638
# ['source_files/2209.06638\\acl2021.tex']
# 3/10 tables collected.
# 3/7 figures collected.
#
#
#  1698 2209.06641
# ['source_files/2209.06641\\PaperForReview.tex', 'source_files/2209.06641\\RebuttalTemplate.tex']
# 6/6 tables collected.
# 1/6 figures collected.
#
#
#  1699 2209.06648
# ['source_files/2209.06648\\algorithmic-repair-app.tex', 'source_files/2209.06648\\algorithmic-repair.tex', 'source_files/2209.06648\\asynchronous-program-app.tex', 'source_files/2209.06648\\asynchronous-program.tex', 'source_files/2209.06648\\asynchrony-synthesis-app.tex', 'source_files/2209.06648\\asynchrony-synthesis-new.tex', 'source_files/2209.06648\\conclusion.tex', 'source_files/2209.06648\\draft.tex', 'source_files/2209.06648\\experiments.tex', 'source_files/2209.06648\\flow-graph-app.tex', 'source_files/2209.06648\\flow-graph.tex', 'source_files/2209.06648\\introduction.tex', 'source_files/2209.06648\\overview-table.tex', 'source_files/2209.06648\\preliminary-app.tex', 'source_files/2209.06648\\preliminary.tex', 'source_files/2209.06648\\reachability-reduction-app.tex', 'source_files/2209.06648\\reachability-reduction.tex', 'source_files/2209.06648\\related-work.tex', 'source_files/2209.06648\\start-join.tex']
# 4/4 tables collected.
# 1/15 figures collected.
#
#
#  1700 2209.06650
# ['source_files/2209.06650\\main.camera.ready.tex', 'source_files/2209.06650\\unused\\results.tex']
# 0/28 tables collected.
# 0/17 figures collected.
#
#
#  1701 2209.06664
# ['source_files/2209.06664\\sample-sigconf.tex']
# 6/11 tables collected.
# 1/5 figures collected.
#
#
#  1702 2209.06668
# ['source_files/2209.06668\\main_v2.tex', 'source_files/2209.06668\\old\\sections\\1-intro1.tex', 'source_files/2209.06668\\old\\sections\\2-related1.tex', 'source_files/2209.06668\\old\\sections\\3-dataset1.tex', 'source_files/2209.06668\\old\\sections\\4-method1.tex', 'source_files/2209.06668\\old\\sections\\5-results1.tex', 'source_files/2209.06668\\old\\sections\\6-conclusion1.tex', 'source_files/2209.06668\\sections_v2\\1-intro.tex', 'source_files/2209.06668\\sections_v2\\2-related.tex', 'source_files/2209.06668\\sections_v2\\3-dataset.tex', 'source_files/2209.06668\\sections_v2\\4-method.tex', 'source_files/2209.06668\\sections_v2\\5-results.tex', 'source_files/2209.06668\\sections_v2\\6-conclusion.tex']
# 17/21 tables collected.
# 2/4 figures collected.
#
#
#  1703 2209.06691
# ['source_files/2209.06691\\arxiv.tex', 'source_files/2209.06691\\authors.tex', 'source_files/2209.06691\\meta.tex', 'source_files/2209.06691\\packages.tex']
# 0/4 tables collected.
# 0/3 figures collected.
#
#
#  1704 2209.06695
# ['source_files/2209.06695\\3-C-FPT.tex']
# 0/0 tables collected.
# 1/2 figures collected.
#
#
#  1705 2209.06699
# ['source_files/2209.06699\\main.tex']
# 9/10 tables collected.
# 0/0 figures collected.
#
#
#  1706 2209.06710
# ['source_files/2209.06710\\macros.tex', 'source_files/2209.06710\\main.tex', 'source_files/2209.06710\\sections\\cityscapes_and_gta.tex', 'source_files/2209.06710\\sections\\conclusion.tex', 'source_files/2209.06710\\sections\\epe_simulation.tex', 'source_files/2209.06710\\sections\\introduction.tex']
# 1/1 tables collected.
# 1/6 figures collected.
#
#
#  1707 2209.06717
# ['source_files/2209.06717\\main.tex', 'source_files/2209.06717\\regex_task1.tex', 'source_files/2209.06717\\regex_task2.tex', 'source_files/2209.06717\\figures\\dist_bar_plot.tex', 'source_files/2209.06717\\figures\\OOV_len_dist.tex', 'source_files/2209.06717\\figures\\spatial_dist.tex', 'source_files/2209.06717\\plots\\length_analysis_crops.tex', 'source_files/2209.06717\\plots\\length_analysis_e2e.tex', 'source_files/2209.06717\\sota\\sota.tex', 'source_files/2209.06717\\tables\\dataset_stats.tex', 'source_files/2209.06717\\tables\\e2e.tex', 'source_files/2209.06717\\tables\\recognition.tex']
# 2/3 tables collected.
# 2/7 figures collected.
#
#
#  1708 2209.06730
# ['source_files/2209.06730\\main.tex', 'source_files/2209.06730\\tables\\stvqa-iid.tex', 'source_files/2209.06730\\tables\\stvqa-only_english.tex', 'source_files/2209.06730\\tables\\stvqa-zero_shot.tex', 'source_files/2209.06730\\tables\\stvqa_translate_robustness-tabular.tex', 'source_files/2209.06730\\tables\\stvqa_translate_robustness.tex', 'source_files/2209.06730\\tables\\textvqa-iid.tex', 'source_files/2209.06730\\tables\\textvqa-only_english.tex', 'source_files/2209.06730\\tables\\textvqa-zero_shot.tex', 'source_files/2209.06730\\tables\\textvqa_translate_robustness-tabular.tex', 'source_files/2209.06730\\tables\\textvqa_translate_robustness.tex']
# 5/10 tables collected.
# 1/5 figures collected.
#
#
#  1709 2209.06744
# ['source_files/2209.06744\\main.tex']
# 0/0 tables collected.
# 4/4 figures collected.
#
#
#  1710 2209.06750
# ['source_files/2209.06750\\Liberty_Extended.tex']
# 2/6 tables collected.
# 0/1 figures collected.
#
#
#  1711 2209.06792
# ['source_files/2209.06792\\acl_latex.tex']
# 8/15 tables collected.
# 5/19 figures collected.
#
#
#  1712 2209.06813
# ['source_files/2209.06813\\appendix.tex', 'source_files/2209.06813\\conclusion.tex', 'source_files/2209.06813\\dataset.tex', 'source_files/2209.06813\\intro.tex', 'source_files/2209.06813\\main.tex', 'source_files/2209.06813\\method.tex', 'source_files/2209.06813\\problem.tex', 'source_files/2209.06813\\related.tex', 'source_files/2209.06813\\results.tex']
# 6/7 tables collected.
# 3/8 figures collected.
#
#
#  1713 2209.06819
# ['source_files/2209.06819\\abstract.tex', 'source_files/2209.06819\\conclusions.tex', 'source_files/2209.06819\\encodeMixedSessions.tex', 'source_files/2209.06819\\eptcsdata.tex', 'source_files/2209.06819\\introduction.tex', 'source_files/2209.06819\\main.tex', 'source_files/2209.06819\\preliminaries.tex', 'source_files/2209.06819\\separateMixedSessionsFromPiLeaderElection.tex', 'source_files/2209.06819\\separateMixedSessionsFromPiSynchronisationPatterns.tex']
# 0/0 tables collected.
# 0/1 figures collected.
#
#
#  1714 2201.00875
# ['source_files/2201.00875\\metrics.tex']
# 0/0 tables collected.
# 0/5 figures collected.
#
#
#  1715 2201.02495
# ['source_files/2201.02495\\00_main_arxiv_v2.tex', 'source_files/2201.02495\\01_abstract.tex', 'source_files/2201.02495\\02_intro.tex', 'source_files/2201.02495\\03_related-work.tex', 'source_files/2201.02495\\04_method.tex', 'source_files/2201.02495\\05_experiments.tex', 'source_files/2201.02495\\06_conclusion.tex', 'source_files/2201.02495\\08_appendix.tex', 'source_files/2201.02495\\Tables\\ablation-feature-aggregation-bobsl.tex', 'source_files/2201.02495\\Tables\\ablation-feature-aggregation.tex', 'source_files/2201.02495\\Tables\\ablation-text-embedding-bobsl.tex', 'source_files/2201.02495\\Tables\\ablation-text-embedding.tex', 'source_files/2201.02495\\Tables\\alignment-bobsl.tex', 'source_files/2201.02495\\Tables\\alignment.tex', 'source_files/2201.02495\\Tables\\automatic_annotations_stats.tex', 'source_files/2201.02495\\Tables\\ensembling-bobsl.tex', 'source_files/2201.02495\\Tables\\ensembling.tex', 'source_files/2201.02495\\Tables\\features-bobsl.tex', 'source_files/2201.02495\\Tables\\features.tex', 'source_files/2201.02495\\Tables\\phoenix14-retrieval.tex', 'source_files/2201.02495\\Tables\\supmat-initialisation.tex', 'source_files/2201.02495\\Tables\\threshold-bobsl.tex', 'source_files/2201.02495\\Tables\\threshold.tex', "source_files/2201.02495\\[CVPR'22] Amanda\\00_main_arxiv_v2.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\01_abstract.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\02_intro.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\03_related-work.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\04_method.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\05_experiments.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\06_conclusion.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\08_appendix.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\Tables\\ablation-feature-aggregation-bobsl.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\Tables\\ablation-feature-aggregation.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\Tables\\ablation-text-embedding-bobsl.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\Tables\\ablation-text-embedding.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\Tables\\alignment-bobsl.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\Tables\\alignment.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\Tables\\automatic_annotations_stats.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\Tables\\ensembling-bobsl.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\Tables\\ensembling.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\Tables\\features-bobsl.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\Tables\\features.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\Tables\\phoenix14-retrieval.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\Tables\\supmat-initialisation.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\Tables\\threshold-bobsl.tex", "source_files/2201.02495\\[CVPR'22] Amanda\\Tables\\threshold.tex"]
# 4/32 tables collected.
# 2/16 figures collected.
#
#
#  1716 2201.03101
# ['source_files/2201.03101\\PaperForReview.tex']
# 0/5 tables collected.
# 0/8 figures collected.
#
#
#  1717 2201.07601
# ['source_files/2201.07601\\root.tex', 'source_files/2201.07601\\tmp.tex', 'source_files/2201.07601\\old_files\\reply_to_reviewers.tex', 'source_files/2201.07601\\old_files\\revision.tex', 'source_files/2201.07601\\old_files\\root.tex']
# 7/7 tables collected.
# 14/47 figures collected.
#
#
#  1718 2202.02281
# ['source_files/2202.02281\\PT_access.tex', 'source_files/2202.02281\\PTaccess\\sec_discussion.tex', 'source_files/2202.02281\\PTaccess\\sec_intro.tex', 'source_files/2202.02281\\PTaccess\\sec_methods.tex', 'source_files/2202.02281\\PTaccess\\sec_relatedwork.tex', 'source_files/2202.02281\\PTaccess\\sec_results.tex', 'source_files/2202.02281\\samples\\sample-acmlarge.tex', 'source_files/2202.02281\\samples\\sample-acmsmall-conf.tex', 'source_files/2202.02281\\samples\\sample-acmsmall-submission.tex', 'source_files/2202.02281\\samples\\sample-acmsmall.tex', 'source_files/2202.02281\\samples\\sample-acmtog.tex', 'source_files/2202.02281\\samples\\sample-authordraft.tex', 'source_files/2202.02281\\samples\\sample-lualatex.tex', 'source_files/2202.02281\\samples\\sample-manuscript.tex', 'source_files/2202.02281\\samples\\sample-sigconf.tex', 'source_files/2202.02281\\samples\\sample-sigplan.tex', 'source_files/2202.02281\\samples\\sample-xelatex.tex']
# 22/24 tables collected.
# 0/11 figures collected.
